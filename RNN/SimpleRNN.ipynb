# %%
import numpy as np
from keras.datasets import imdb
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /home/daniel/Documents/AI/RNN/SimpleRNN.ipynb Cell 1' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/home/daniel/Documents/AI/RNN/SimpleRNN.ipynb#ch0000000?line=0'>1</a> import numpy as np
# ----> <a href='vscode-notebook-cell:/home/daniel/Documents/AI/RNN/SimpleRNN.ipynb#ch0000000?line=1'>2</a> from keras.datasets import imdb
#
# File ~/Documents/AI/venv/lib/python3.10/site-packages/keras/__init__.py:21, in <module>
#      <a href='file:///home/daniel/Documents/AI/venv/lib/python3.10/site-packages/keras/__init__.py?line=14'>15</a> """Implementation of the Keras API, the high-level API of TensorFlow.
#      <a href='file:///home/daniel/Documents/AI/venv/lib/python3.10/site-packages/keras/__init__.py?line=15'>16</a>
# ...
